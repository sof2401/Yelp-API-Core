# %%
import json
with open('/Users/sofiawang/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
from yelpapi import YelpAPI
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='food')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 27300

# %%
import pandas as pd
biz= pd.DataFrame(search_results['businesses'])
biz.head()
# Out:
#                        id                                      alias  \
# 0  MGd6HFEq1ALD58XWNviSXw          time-out-market-new-york-brooklyn
# 1  nMyot99PkX5iYCdxHoRJqQ                            ariari-new-york
# 2  fVbUVAiLiGgLA_nxBFxyww                  thursday-kitchen-new-york
# 3  3UdlrH-tuVM0vy3ySh7bUw  jacobs-pickles-time-out-market-brooklyn-2
# 4  miYWrEThPPhB7AW0A72WHw                     silky-kitchen-brooklyn
#
#                               name  \
# 0         Time Out Market New York
# 1                           ARIARI
# 2                 Thursday Kitchen
# 3  Jacob's Pickles Time Out Market
# 4                    Silky Kitchen
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/Y41f8m...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/IQbVjJ...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/rNxrGd...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/8-aQ6G...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/Jf0cTl...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/time-out-market-new-y...           552
# 1  https://www.yelp.com/biz/ariari-new-york?adjus...           267
# 2  https://www.yelp.com/biz/thursday-kitchen-new-...          1808
# 3  https://www.yelp.com/biz/jacobs-pickles-time-o...           112
# 4  https://www.yelp.com/biz/silky-kitchen-brookly...             4
#
#                                           categories  rating  \
# 0   [{'alias': 'food_court', 'title': 'Food Court'}]     4.0
# 1  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 2  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 3  [{'alias': 'comfortfood', 'title': 'Comfort Fo...     4.5
# 4         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.70342863348067, 'longitude': -...                  []
# 1  {'latitude': 40.727283504010266, 'longitude': ...                  []
# 2     {'latitude': 40.72761, 'longitude': -73.98373}  [pickup, delivery]
# 3  {'latitude': 40.70341672927573, 'longitude': -...          [delivery]
# 4   {'latitude': 40.692009, 'longitude': -73.986618}                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '55 Water St', 'address2': '', 'a...  +19178104855
# 1   NaN  {'address1': '119 1st Ave', 'address2': None, ...  +16464227466
# 2    $$  {'address1': '424 E 9th St', 'address2': None,...
# 3    $$  {'address1': '55 Water St', 'address2': None, ...  +12124705566
# 4   NaN  {'address1': '56 Willoughby St', 'address2': N...  +13475295693
#
#     display_phone     distance
# 0  (917) 810-4855   288.119008
# 1  (646) 422-7466  2530.901207
# 2                  2617.644845
# 3  (212) 470-5566   319.425646
# 4  (347) 529-5693  1627.613419

# %%
len(search_results['businesses'])
# Out:
# 20

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='NY, NY',
                                       term='Pizza',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                           alias  \
# 0  4h4Tuuc56YPO6lWfZ1bdSQ         joes-pizza-new-york-152
# 1  oJ_XSPZFpvIt6rvheSQl7A  bleecker-street-pizza-new-york
#
#                     name                                          image_url  \
# 0            Joe's Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/sUjegc...
# 1  Bleecker Street Pizza  https://s3-media1.fl.yelpcdn.com/bphoto/uScs5H...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/joes-pizza-new-york-1...           546
# 1      False  https://www.yelp.com/biz/bleecker-street-pizza...          2996
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.7101297729083, 'longitude': -7...  [pickup, delivery]
# 1  {'latitude': 40.7320627016512, 'longitude': -7...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0     $  {'address1': '124 Fulton St', 'address2': '', ...  +12122670860
# 1     $  {'address1': '69 7th Ave S', 'address2': None,...  +12129244466
#
#     display_phone     distance
# 0  (212) 267-0860  1245.942863
# 1  (212) 924-4466  3073.574220

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                              alias  \
# 0  MGd6HFEq1ALD58XWNviSXw  time-out-market-new-york-brooklyn
# 1  nMyot99PkX5iYCdxHoRJqQ                    ariari-new-york
# 2  fVbUVAiLiGgLA_nxBFxyww          thursday-kitchen-new-york
#
#                        name  \
# 0  Time Out Market New York
# 1                    ARIARI
# 2          Thursday Kitchen
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/Y41f8m...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/IQbVjJ...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/rNxrGd...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/time-out-market-new-y...           552
# 1  https://www.yelp.com/biz/ariari-new-york?adjus...           267
# 2  https://www.yelp.com/biz/thursday-kitchen-new-...          1808
#
#                                           categories  rating  \
# 0   [{'alias': 'food_court', 'title': 'Food Court'}]     4.0
# 1  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 2  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.70342863348067, 'longitude': -...                  []
# 1  {'latitude': 40.727283504010266, 'longitude': ...                  []
# 2     {'latitude': 40.72761, 'longitude': -73.98373}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '55 Water St', 'address2': '', 'a...  +19178104855
# 1   NaN  {'address1': '119 1st Ave', 'address2': None, ...  +16464227466
# 2    $$  {'address1': '424 E 9th St', 'address2': None,...
#
#     display_phone     distance
# 0  (917) 810-4855   288.119008
# 1  (646) 422-7466  2530.901207
# 2                  2617.644845
#                         id                                  alias  \
# 37  affWh2WFSMayL04l9lr47g                     roberta-s-brooklyn
# 38  Aazjxg21VH2cncWYBAv68Q          sottocasa-pizzeria-brooklyn-3
# 39  afuiZyn9oOyyCpuW7wGfHQ  l-antica-pizzeria-da-michele-new-york
#
#                             name  \
# 37                     Roberta’s
# 38            Sottocasa Pizzeria
# 39  L’Antica Pizzeria da Michele
#
#                                             image_url  is_closed  \
# 37  https://s3-media2.fl.yelpcdn.com/bphoto/POEX_n...      False
# 38  https://s3-media2.fl.yelpcdn.com/bphoto/7lc4CS...      False
# 39  https://s3-media4.fl.yelpcdn.com/bphoto/ToekId...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/roberta-s-brooklyn?ad...            14
# 38  https://www.yelp.com/biz/sottocasa-pizzeria-br...           729
# 39  https://www.yelp.com/biz/l-antica-pizzeria-da-...           121
#
#                                            categories  rating  \
# 37             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 38  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 39  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
#
#                                           coordinates        transactions  \
# 37  {'latitude': 40.71613781459604, 'longitude': -...                  []
# 38   {'latitude': 40.688285, 'longitude': -73.989006}          [delivery]
# 39   {'latitude': 40.737052, 'longitude': -74.001571}  [pickup, delivery]
#
#    price                                           location         phone  \
# 37   NaN  {'address1': '6 Grand St', 'address2': '', 'ad...  +17182782400
# 38    $$  {'address1': '298 Atlantic Ave', 'address2': N...  +17188528758
# 39   $$$  {'address1': '81 Greenwich Ave', 'address2': N...  +19295246682
#
#      display_phone     distance
# 37  (718) 278-2400  2620.492306
# 38  (718) 852-8758  1955.310589
# 39  (929) 524-6682  3560.290394
