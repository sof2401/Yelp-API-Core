# %%
# Open the jsonfile and display the first level of keys
# open API results WITH json module
import json
with open('Data/example_yelp_results.json') as f:   #adjust for your path
    json_file = json.load(f)
    
## What type is top-level of json?
type(json_file)
# Out:
# dict

# %%
json_file.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
# REGION
type(json_file['region'])
# Out:
# dict

# %%
json_file['region'].keys()
# Out:
# dict_keys(['center'])

# %%
json_file['region']['center'].keys()
# Out:
# dict_keys(['longitude', 'latitude'])

# %%
json_file['region']['center']
# Out:
# {'longitude': -76.607666015625, 'latitude': 39.29617825404647}

# %%
# TOTAL 
type(json_file['total'])
# Out:
# int

# %%
json_file['total']
# Out:
# 435

# %%
# BUSINESSES
type(json_file['businesses'])
# Out:
# list

# %%
len(json_file['businesses'])
# Out:
# 20

# %%
json_file['businesses'][0]
# Out:
# {'id': 'D9A33FM394q99o4QtK5YwA',
#  'alias': 'faidleys-seafood-baltimore-3',
#  'name': 'Faidleys Seafood',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OTjVDCVS7pGopH6GZcfjBA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/faidleys-seafood-baltimore-3?adjust_creative=KJtcufKUS887p24u6rjVIQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=KJtcufKUS887p24u6rjVIQ',
#  'review_count': 1184,
#  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#   {'alias': 'beerbar', 'title': 'Beer Bar'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 39.291696, 'longitude': -76.62224},
#  'transactions': ['delivery'],
#  'price': '$$',
#  'location': {'address1': '203 N Paca St',
#   'address2': '',
#   'address3': '',
#   'city': 'Baltimore',
#   'zip_code': '21201',
#   'country': 'US',
#   'state': 'MD',
#   'display_address': ['203 N Paca St', 'Baltimore, MD 21201']},
#  'phone': '+14107274898',
#  'display_phone': '(410) 727-4898',
#  'distance': 1349.560720156645}

# %%
## what are the keys of the first entry in businesses?
json_file['businesses'][0].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'price', 'location', 'phone', 'display_phone', 'distance'])

# %%
## what are the keys of the next entry in businesses? do they match?
json_file['businesses'][1].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'price', 'location', 'phone', 'display_phone', 'distance'])

# %%
# IDENTIFYING RECORDS
import pandas as pd
df_businesses= pd.DataFrame(json_file['businesses'])
df_businesses
# Out:
#                         id                                              alias  \
# 0   D9A33FM394q99o4QtK5YwA                       faidleys-seafood-baltimore-3
# 1   u65W69AhbjUlvJJBkEhGNQ                     miss-shirleys-cafe-baltimore-9
# 2   ieS_5zqxDHcWMCm8BKUYbg               thames-street-oyster-house-baltimore
# 3   6am8TZAFnvND52MOz-Yctg                  mamas-on-the-half-shell-baltimore
# 4   ISn7WyGQaFpsVSRSh0NSqg                             sal-and-sons-baltimore
# 5   UplfpgvI5BfuDjtolDrmsA                          blackwall-hitch-baltimore
# 6   p_XPpHiZbdOccx2jFUgZJA                         the-local-oyster-baltimore
# 7   fdo4pqfSYjQyW5_-rElfew                      faidley-s-seafood-baltimore-2
# 6   https://www.yelp.com/biz/the-local-oyster-balt...           217
# 7   https://www.yelp.com/biz/faidley-s-seafood-bal...            39
# 8   https://www.yelp.com/biz/the-water-street-tave...           263
# 9   https://www.yelp.com/biz/angies-seafood-baltim...           672
# 10  https://www.yelp.com/biz/l-p-steamers-baltimor...          1674
# 11  https://www.yelp.com/biz/clock-restoration-bal...            30
# 12  https://www.yelp.com/biz/b-and-o-american-bras...           576
# 13  https://www.yelp.com/biz/peters-pour-house-bal...           228
# 14  https://www.yelp.com/biz/phillips-seafood-balt...          1493
# 15  https://www.yelp.com/biz/masons-famous-lobster...           171
# 16  https://www.yelp.com/biz/fishnet-baltimore-2?a...            56
# 17  https://www.yelp.com/biz/lexington-market-balt...           356
# 18  https://www.yelp.com/biz/blue-moon-cafe-baltim...          2300
# 19  https://www.yelp.com/biz/mount-vernon-marketpl...           230
#
#                                            categories  rating  \
# 0   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1   [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 2   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 3   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0
# 4   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 5   [{'alias': 'newamerican', 'title': 'American (...     4.0
# 6   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 7   [{'alias': 'seafoodmarkets', 'title': 'Seafood...     4.0
# 8   [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 9   [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 10         [{'alias': 'seafood', 'title': 'Seafood'}]     4.0
# 11  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     5.0
# 12  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 13  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 14  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.0
# 15  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 16  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 17  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     3.5
# 18  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 19   [{'alias': 'food_court', 'title': 'Food Court'}]     4.5
#
#                                           coordinates        transactions  \
# 0     {'latitude': 39.291696, 'longitude': -76.62224}          [delivery]
# 1   {'latitude': 39.2870995, 'longitude': -76.6053...  [delivery, pickup]
# 2      {'latitude': 39.28214, 'longitude': -76.59162}          [delivery]
# 3    {'latitude': 39.27986, 'longitude': -76.5752399}  [delivery, pickup]
# 4        {'latitude': 39.284, 'longitude': -76.59337}          [delivery]
# 5   {'latitude': 39.2871515492791, 'longitude': -7...                  []
# 6   {'latitude': 39.2958288, 'longitude': -76.6188...          [delivery]
# 7   {'latitude': 39.2915897, 'longitude': -76.6222...                  []
# 8    {'latitude': 39.288553, 'longitude': -76.613303}          [delivery]
# 9   {'latitude': 39.289207148922245, 'longitude': ...  [delivery, pickup]
# 10     {'latitude': 39.27093, 'longitude': -76.59861}          [delivery]
# 11     {'latitude': 39.28807, 'longitude': -76.61196}  [delivery, pickup]
# 12  {'latitude': 39.2899436853933, 'longitude': -7...  [delivery, pickup]
# 13  {'latitude': 39.288481314045015, 'longitude': ...  [delivery, pickup]
# 14  {'latitude': 39.286385925645, 'longitude': -76...  [delivery, pickup]
# 15     {'latitude': 39.28619, 'longitude': -76.61099}  [delivery, pickup]
# 16  {'latitude': 39.29584261917888, 'longitude': -...  [delivery, pickup]
# 17    {'latitude': 39.29198, 'longitude': -76.622342}                  []
# 18  {'latitude': 39.283401121424866, 'longitude': ...          [delivery]
# 19   {'latitude': 39.295902, 'longitude': -76.618819}                  []
#
#    price                                           location         phone  \
# 0     $$  {'address1': '203 N Paca St', 'address2': '', ...  +14107274898
# 1     $$  {'address1': '750 E Pratt St', 'address2': '',...  +14105285373
# 2    $$$  {'address1': '1728 Thames St', 'address2': '',...  +14434497726
# 3     $$  {'address1': '2901 Odonnell St', 'address2': '...  +14102763160
# 4      $  {'address1': '1640 Aliceanna St', 'address2': ...  +14106751466
# 5     $$  {'address1': '700 E Pratt St', 'address2': Non...  +14437597176
# 6     $$  {'address1': '520 Park Ave', 'address2': None,...  +18447482537
# 7      $  {'address1': '203 N Paca St', 'address2': '', ...  +14107526461
# 8     $$  {'address1': '102 Water St', 'address2': '', '...  +14106059495
# 9     $$  {'address1': '1727 E Pratt St', 'address2': No...  +14103420917
# 10    $$  {'address1': '1100 E Fort Ave', 'address2': ''...  +14105769294
# 11   NaN  {'address1': '31 S Calvert St', 'address2': 'F...  +14106857428
# 12    $$  {'address1': '2 N Charles St', 'address2': '',...  +14436926172
# 13    $$  {'address1': '111 Mercer St', 'address2': None...  +14105395818
# 14    $$  {'address1': '601 E Pratt St', 'address2': '',...  +14106856600
# 15    $$  {'address1': '201 E Pratt St', 'address2': Non...  +14434539664
# 16    $$  {'address1': '520 Park Ave', 'address2': None,...  +14438696399
# 17     $  {'address1': '400 W Lexington St', 'address2':...  +14106856169
# 18    $$  {'address1': '1621 Aliceanna St', 'address2': ...  +14105223940
# 19    $$  {'address1': '520 Park Ave', 'address2': '', '...  +14437967393
#
#      display_phone     distance
# 0   (410) 727-4898  1349.560720
# 1   (410) 528-5373  1028.736468
# 2   (443) 449-7726  2090.712792
# 3   (410) 276-3160  3328.825798
# 4   (410) 675-1466  1817.406978
# 5   (443) 759-7176  1013.275577
# 6   (844) 748-2537   966.729941
# 7   (410) 752-6461  1342.513104
# 8   (410) 605-9495   976.849894
# 9   (410) 342-0917  1499.083404
# 10  (410) 576-9294  2918.315725
# 11  (410) 685-7428   975.367255
# 12  (443) 692-6172   958.642226
# 13  (410) 539-5818   972.436126
# 14  (410) 685-6600  1089.215502
# 15  (443) 453-9664  1144.015776
# 16  (443) 869-6399   927.361011
# 17  (410) 685-6169  1346.447303
# 18  (410) 522-3940  1830.489812
# 19  (443) 796-7393   960.226708

# %%
df_businesses[['categories','coordinates','location']].head(3)
# Out:
#                                           categories  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 1  [{'alias': 'breakfast_brunch', 'title': 'Break...
# 2  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
#
#                                          coordinates  \
# 0    {'latitude': 39.291696, 'longitude': -76.62224}
# 1  {'latitude': 39.2870995, 'longitude': -76.6053...
# 2     {'latitude': 39.28214, 'longitude': -76.59162}
#
#                                             location
# 0  {'address1': '203 N Paca St', 'address2': '', ...
# 1  {'address1': '750 E Pratt St', 'address2': '',...
# 2  {'address1': '1728 Thames St', 'address2': '',...
